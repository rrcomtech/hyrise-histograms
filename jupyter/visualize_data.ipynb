# %% [markdown]
# # visualize_cardinalities

# %% [markdown]
# ## imports

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt

# %% [markdown]
# ## load data

# %%
equaldistinctcount_df = pd.read_csv('data/tpch_s001_r1_equaldistinctcount.csv')
equiheight_df = pd.read_csv('data/tpch_s001_r1_equiheight.csv')
maxdifffr_df = pd.read_csv('data/tpch_s001_r1_maxdifffr.csv')

# %%
def generate_errors(df):
    df['absolute_error'] = df['estimated_output'] - df['real_output']
    df['relative_error'] = df['absolute_error'] / df['real_output']
    df['x'] = df['estimated_output'] / df['real_output']
    df['1/x'] = 1 / df['x']
    df['q_error'] = df[['x','1/x']].max(axis=1)
    df.drop(['x', '1/x'], axis=1, inplace = True)

    
def generate_MSE(df):
    mse = 0
    for index, row in df.iterrows():
        mse += row['absolute_error'] ** 2
    return mse / df.size

# %% [markdown]
# ## examine data

# %%
generate_errors(equaldistinctcount_df)
generate_errors(equiheight_df)
generate_errors(maxdifffr_df)

# %%
print("Mean squared errors EqualDistinctCount: " + str(generate_MSE(equaldistinctcount_df)))
print("Mean squared errors EquiHeight: " + str(generate_MSE(equiheight_df)))
print("Mean squared errors MaxDiffFr: " + str(generate_MSE(maxdifffr_df)))
# Out:
# Mean squared errors EqualDistinctCount: 9079722.553368965
# Mean squared errors EquiHeight: 8497968.138165666
# Mean squared errors MaxDiffFr: 8619139.694100708

# %%
equaldistinctcount_df = equaldistinctcount_df.iloc[1:17]
equiheight_df = equiheight_df.iloc[1:17]
maxdifffr_df = maxdifffr_df.iloc[1:17]

# %%
equiheight_df
# Out:
#           name  operator_type  real_input  real_output  estimated_input  \
# 1   TPC-H 0216      TableScan        2000           27           2000.0
# 2   TPC-H 0217   JoinHashLeft        8000           36           8000.0
# 3   TPC-H 0218   JoinHashLeft         100           12            100.0
# 4   TPC-H 0219   JoinHashLeft         100           12            100.0
# 5   TPC-H 0220   JoinHashLeft          25            5             25.0
# 6   TPC-H 0224   JoinHashLeft          25            5             25.0
# 7   TPC-H 0229      TableScan           5            1              5.0
# 8   TPC-H 0230      TableScan           5            1              5.0
# 9   TPC-H 0311   JoinHashLeft       60175         4911          60175.0
# 10  TPC-H 0312   JoinHashLeft       15000         2536          15000.0
# 11  TPC-H 0316      TableScan        1500          288           1500.0
# 12   TPC-H 046      TableScan       15000          544          15000.0
# ...

# %%
equaldistinctcount_df
# Out:
#           name  operator_type  real_input  real_output  estimated_input  \
# 1   TPC-H 0216      TableScan        2000           27           2000.0
# 2   TPC-H 0217   JoinHashLeft        8000           36           8000.0
# 3   TPC-H 0218   JoinHashLeft         100           12            100.0
# 4   TPC-H 0219   JoinHashLeft         100           12            100.0
# 5   TPC-H 0220   JoinHashLeft          25            5             25.0
# 6   TPC-H 0224   JoinHashLeft          25            5             25.0
# 7   TPC-H 0229      TableScan           5            1              5.0
# 8   TPC-H 0230      TableScan           5            1              5.0
# 9   TPC-H 0311   JoinHashLeft       60175         4911          60175.0
# 10  TPC-H 0312   JoinHashLeft       15000         2536          15000.0
# 11  TPC-H 0316      TableScan        1500          288           1500.0
# 12   TPC-H 046      TableScan       15000          544          15000.0
# ...

# %%
maxdifffr_df
# Out:
#           name  operator_type  real_input  real_output  estimated_input  \
# 1   TPC-H 0216      TableScan        2000           27           2000.0
# 2   TPC-H 0217   JoinHashLeft        8000           36           8000.0
# 3   TPC-H 0218   JoinHashLeft         100           12            100.0
# 4   TPC-H 0219   JoinHashLeft         100           12            100.0
# 5   TPC-H 0220   JoinHashLeft          25            5             25.0
# 6   TPC-H 0224   JoinHashLeft          25            5             25.0
# 7   TPC-H 0229      TableScan           5            1              5.0
# 8   TPC-H 0230      TableScan           5            1              5.0
# 9   TPC-H 0311   JoinHashLeft       60175         4911          60175.0
# 10  TPC-H 0312   JoinHashLeft       15000         2536          15000.0
# 11  TPC-H 0316      TableScan        1500          288           1500.0
# 12   TPC-H 046      TableScan       15000          544          15000.0
# ...

# %% [markdown]
# ## plot

# %%
matplotlib.rc_file_defaults()
ax1 = sns.set_style(style=None, rc=None )

fig, ax1 = plt.subplots(figsize=(18,6))

sns.lineplot(data = equaldistinctcount_df['estimated_output'], marker='o', sort = False, ax=ax1)
sns.lineplot(data = equiheight_df['estimated_output'], marker='x', sort = False, ax=ax1)
sns.lineplot(data = maxdifffr_df['estimated_output'], marker='x', sort = False, ax=ax1)

plt.legend(title='Graphs', loc='upper left', labels=['Equal Distinct Count', 'Equi Height', 'Max Diff (Fr)'])

ax2 = ax1.twinx()

sns.barplot(data = equaldistinctcount_df, x='name', y='real_output', alpha=0.75, ax=ax1)
# Out:
# <AxesSubplot:xlabel='name', ylabel='real_output'>

# %%
matplotlib.rc_file_defaults()
ax1 = sns.set_style(style=None, rc=None )

fig, ax1 = plt.subplots(figsize=(18,6))

sns.lineplot(data = equaldistinctcount_df['relative_error'], marker='o', sort = False, ax=ax1)
sns.lineplot(data = equiheight_df['relative_error'], marker='x', sort = False, ax=ax1)
sns.lineplot(data = maxdifffr_df['relative_error'], marker='p', sort = False, ax=ax1)


labels = [
    "Equal Distinct Count",
    "Equi Height",
    "Max Diff (Fr)"
]
plt.legend(title='Relative Errors', loc='upper left', labels=labels)

ax2 = ax1.twinx()

# %%
matplotlib.rc_file_defaults()
ax1 = sns.set_style(style=None, rc=None )

fig, ax1 = plt.subplots(figsize=(18,6))

sns.lineplot(data = equaldistinctcount_df['q_error'], marker='o', sort = False, ax=ax1)
sns.lineplot(data = equiheight_df['q_error'], marker='x', sort = False, ax=ax1)
sns.lineplot(data = maxdifffr_df['q_error'], marker='p', sort = False, ax=ax1)

labels = [
    "Q Error: Equal Distinct Count",
    "Q Error: Equi Height",
    "Q Error: Max Diff (Fr)"
]

plt.legend(title='Q Errors', loc='upper left', labels=labels)

ax2 = ax1.twinx()

# %% [markdown]
# # Histogram Performances

# %%
headers = ["Histogram Name", "Build Time"]
build_times = pd.read_csv('data/histogram_performance.csv', names=headers)

# %%
build_times
# Out:
#                 Histogram Name  Build Time
# 0          EquiHeightHistogram    0.000618
# 1          EquiHeightHistogram    0.000562
# 2          EquiHeightHistogram    0.000580
# 3          EquiHeightHistogram    0.000574
# 4          EquiHeightHistogram    0.000105
# ..                         ...         ...
# 239  MaxDiffFrequencyHistogram    0.060152
# 240  MaxDiffFrequencyHistogram    0.024883
# 241  MaxDiffFrequencyHistogram    0.026236
# 242  MaxDiffFrequencyHistogram    0.384135
# 243  MaxDiffFrequencyHistogram    0.109897
#
# [244 rows x 2 columns]

# %%
matplotlib.rc_file_defaults()
ax1 = sns.set_style(style=None, rc=None)

fig, ax1 = plt.subplots(figsize=(18,6))

sns.barplot(data=build_times, x='Histogram Name', y='Build Time')
# Out:
# <AxesSubplot:xlabel='Histogram Name', ylabel='Build Time'>
